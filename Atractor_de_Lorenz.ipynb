# %% [markdown]
# ## Atractor de Lorenz

# %% [markdown]
# $$ \dot{x}=\sigma (y-x) $$
# $$ \dot{y}=\rho x -y -xz $$
# $$ \dot{z}=-\beta z +xy $$

# %% [markdown]
# * x temperatura
# * y velocidad del viento
# * z la humedad

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
x0,y0,z0=0,1,1.05
sigma,beta,rho=10,2.667,28
tiempo=np.linspace(0,100,10000)

# %%
sistema= lambda var,t : [sigma*(var[1]-var[0]),rho*var[0]-var[1]-var[0]*var[2],-beta*var[2]+var[0]*var[1]]

# %%
sol=odeint(sistema,[x0,y0,z0],tiempo)
xx,yy,zz=sol.T

# %% [markdown]
# ### Solución X contra Y

# %%
plt.scatter(xx,yy,c=xx,cmap='viridis',alpha=0.8,s=3,label="Atractor de Lorenz X contra Y")
plt.xlabel("Variable x")
plt.ylabel("Variable y")
plt.legend()
plt.show()

# %% [markdown]
# ### Solución X contra Z

# %%
plt.scatter(xx,zz,c=xx,cmap='plasma',alpha=0.8,s=3,label="Atractor de Lorenz X contra Z")
plt.xlabel("Variable x")
plt.ylabel("Variable z")
plt.legend();
plt.show()

# %% [markdown]
# ### Solución Y contra Z

# %%
plt.scatter(yy,zz,c=xx,cmap='PiYG',alpha=0.8,s=3,label="Atractor de Lorenz Y contra Z")
plt.xlabel("Variable y")
plt.ylabel("Variable z")
plt.legend()
plt.show()

# %% [markdown]
# ### Solución en 3D

# %%
# %matplotlib inline

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xx,yy,zz,c=xx,cmap='plasma',alpha=0.8,s=3)
plt.show()

# %%
import plotly
import plotly.graph_objs as go
plotly.offline.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
trace1 = go.Scatter3d(
    x=xx,
    y=yy,
    z=zz,
    mode='markers',marker=dict(size=1,color=xx,colorscale='Viridis',opacity=.8))
fig = go.Figure(data=[trace1])
plotly.offline.iplot(fig, filename='simple-3d-scatter')
# Out:
# <div id="91b60705-1fb0-40c5-ba1f-813e8650e698" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("91b60705-1fb0-40c5-ba1f-813e8650e698", [{"marker": {"color": [0.0, 0.09511553966198841, 0.18266806484781772, 0.26560864105955584, 0.34647088084382716, 0.4274762458513865, 0.5106210500595261, 0.5977487504854645, 0.6906111130839112, 0.7909205239607626, 0.9003957258773296, 1.0208025617755698, 1.1539911375397027, 1.3019303157896143, 1.4667403527353091, 1.6507240956611682, 1.8563968927795649, 2.0865149883672234, 2.3441017241611335, 2.6324702452863935, 2.9552406067712873, 3.3163481154760754, 3.7200381952668984, 4.170841102454833, 4.67351730423786, 5.23296083867809, 5.854044010375321, 6.541381883970158, 7.298990223876361, 8.129805905164512, 9.035037443394893, 10.013317398738545, 11.059643664834361, 12.1641293788
# ...
